# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('StudentsPerformance.csv')
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df["gender"].value_counts().plot.bar(color=['blue','red'],figsize=[3,3])
# Out:
# <Axes: xlabel='gender'>

# %%
df['race/ethnicity'].value_counts().plot.barh(color=['red','orange','yellow','green','blue'],figsize=(3,3))
plt.title("Frequency Distribution of Race/Ethnicity",family='Arial',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Frequency Distribution of Race/Ethnicity')

# %%
df[['math score','reading score','writing score']].sum().plot.bar(color=['red','blue','green'],figsize=(3,3))
plt.title('Score',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Score')

# %%
df['parental level of education'].value_counts().plot.bar(figsize=(3,3),color=['black','blue','red'],title='Frequency Distribution of Parental Level of Education')
# Out:
# <Axes: title={'center': 'Frequency Distribution of Parental Level of Education'}, xlabel='parental level of education'>

# %%
df['test preparation course'].value_counts().plot.bar(figsize=(3,3),color=['blue','red'],title='Test Preparation Course')
# Out:
# <Axes: title={'center': 'Test Preparation Course'}, xlabel='test preparation course'>

# %%
fig , axes = plt.subplots(2,2,figsize=(20,12))

axes[0, 0].pie(df['gender'].value_counts(),
               labels=['Female', 'Male'],
               colors=['red', 'green'],
               autopct='%1.1f%%',
               shadow=True,)
axes[0, 0].set_title('Gender Distribution',
                     family='Arial',
                     fontweight='bold')

axes[0, 1].pie(df['race/ethnicity'].value_counts(),
               labels=['Group C', 'Group D','Group B','Group E','Group A'],
               colors=['red','orange','yellow','green','blue'],
               autopct='%1.1f%%',
               shadow=True,
               explode=[0.1,0,0.1,0,0])
axes[0, 1].set_title('Group',
                     family='Arial',
                     fontweight='bold')

axes[1,0].pie(df['parental level of education'].value_counts(),
               labels=['Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"],
               colors=['red', 'green', 'blue', 'cyan','orange','grey'],
               autopct='%1.1f%%',
               shadow=True,
               )
axes[1,0].set_title('Parental Education', 
                     fontsize = 20,
                     family='Arial',
                     fontweight='bold')

axes[1, 1].pie(df[['math score','reading score','writing score']].sum(),
               labels=['math', 'reading','writing'],
               colors=['orange','yellow','blue'],
               autopct='%1.1f%%',
               shadow=True,
               )
axes[1, 1].set_title('Score',
                     family='Arial',
                     fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Score')

# %%
sns.countplot(x='math score',data=df, color = 'skybl')
plt.title('Math Score Comparison',fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sns.countplot(x='math score',data=df, color = 'bright')
#       2 plt.title('Math Score Comparison',fontsize = 20)
#       3 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:2661, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2659 saturation = saturation if fill else 1
#    2660 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2661 color = _default_color(ax.bar, hue, color, kwargs, saturation)
#    2663 count_axis = {"x": "y", "y": "x"}[p.orient]
#    2664 if p.input_format == "wide":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\utils.py:85, in _default_color(method, hue, color, kws, saturation)
#      83 if color is not None:
#      84     if saturation < 1:
# ---> 85         color = desaturate(color, saturation)
#      86     return color
#      88 elif method.__name__ == "plot":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\utils.py:168, in desaturate(color, prop)
#     165     raise ValueError("prop must be between 0 and 1")
#     167 # Get rgb tuple rep
# --> 168 rgb = to_rgb(color)
#     170 # Short circuit to avoid floating point issues
#     171 if prop == 1:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\colors.py:529, in to_rgb(c)
#     527 def to_rgb(c):
#     528     """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 529     return to_rgba(c)[:3]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\colors.py:317, in to_rgba(c, alpha)
#     315     rgba = None
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 317     rgba = _to_rgba_no_colorcycle(c, alpha)
#     318     try:
#     319         _colors_full_map.cache[c, alpha] = rgba
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\colors.py:394, in _to_rgba_no_colorcycle(c, alpha)
#     390             raise ValueError(
#     391                 f"Invalid string grayscale value {orig_c!r}. "
#     392                 f"Value must be within 0-1 range")
#     393         return c, c, c, alpha if alpha is not None else 1.
# --> 394     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     395 # turn 2-D array into 1-D array
#     396 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'bright'

# %%
sns.countplot(x='reading score',data=df, palette = 'bright')
plt.title('Reading Score Comparison',fontsize = 20)
plt.show()
# Out:
# C:\Users\Nit Munjapara\AppData\Local\Temp\ipykernel_3900\2586657028.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='reading score',data=df, palette = 'bright')

# %%
sns.countplot(x='writing score',data=df, palette = 'bright')
plt.title('Writing Score Comparison',fontsize = 20)
plt.show()
# Out:
# C:\Users\Nit Munjapara\AppData\Local\Temp\ipykernel_3900\1506143766.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='writing score',data=df, palette = 'bright')
